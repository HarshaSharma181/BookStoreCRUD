# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaSharma181/BookStoreCRUD/blob/main/AirQuality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file="/content/Air_Quality.csv"
df=pd.read_csv(file)
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18025 entries, 0 to 18024
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unique ID      18025 non-null  int64
#  1   Indicator ID   18025 non-null  int64
#  2   Name           18025 non-null  object
#  3   Measure        18025 non-null  object
#  4   Measure Info   18025 non-null  object
#  5   Geo Type Name  18025 non-null  object
#  6   Geo Join ID    18016 non-null  float64
#  7   Place          18016 non-null  object
#  8   Time Period    18025 non-null  object
#  9   Start_Date     18025 non-null  object
#  10  Data Value     18025 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.5+ MB
#            Unique ID  Indicator ID   Geo Join ID    Data Value
# count   18025.000000  18025.000000  1.801600e+04  18025.000000
# mean   426387.692705    434.830180  5.906303e+05     21.428616
# std    250489.450630    115.852371  7.769549e+06     23.999345
# min    121644.000000    365.000000  1.000000e+00      0.000000
# 25%    175303.000000    365.000000  2.020000e+02      8.900000
# 50%    410803.000000    375.000000  3.030000e+02     15.200000
# 75%    649893.000000    386.000000  4.040000e+02     26.700000
# max    828353.000000    661.000000  1.051061e+08    424.700000

# %%
if 'Place' in df.columns:
  group_data=df.groupby('Place')
  for place,group in group_data:
    print(place)
    print(group)
# Out:
# Streaming output truncated to the last 5000 lines.
# 17805     213250           375                Nitrogen dioxide (NO2)
# 17806     603016           375                Nitrogen dioxide (NO2)
# 17993     154528           644  Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 167             Mean           mcg/m3            CD        304.0
# 168             Mean           mcg/m3            CD        304.0
# 169             Mean           mcg/m3            CD        304.0
# 184             Mean              ppb            CD        304.0
# 186             Mean              ppb            CD        304.0
# ...              ...              ...           ...          ...
# 17729           Mean           mcg/m3            CD        304.0
# 17730           Mean           mcg/m3            CD        304.0
# 17805           Mean              ppb            CD        304.0
# 17806           Mean              ppb            CD        304.0
# 17993  Million miles  per square mile            CD        304.0
#
#                 Place          Time Period  Start_Date  Data Value
# 167    Bushwick (CD4)       Winter 2014-15  12-01-2014         9.4
# 168    Bushwick (CD4)  Annual Average 2018  01-01-2018         7.5
# 169    Bushwick (CD4)       Winter 2021-22  12-01-2021         7.3
# 184    Bushwick (CD4)       Winter 2019-20  12-01-2019        27.7
# 186    Bushwick (CD4)          Summer 2015  06-01-2015        15.5
# ...               ...                  ...         ...         ...
# 17729  Bushwick (CD4)       Winter 2013-14  12-01-2013        12.1
# 17730  Bushwick (CD4)  Annual Average 2022  01-01-2022         6.3
# 17805  Bushwick (CD4)       Winter 2013-14  12-01-2013        29.0
# 17806  Bushwick (CD4)       Winter 2017-18  12-01-2017        26.5
# 17993  Bushwick (CD4)                 2005  01-01-2005        35.3
#
# [110 rows x 11 columns]
# Canarsie - Flatlands
#        Unique ID  Indicator ID                                  Name  \
# 68        742205           365               Fine particles (PM 2.5)
# 69        547411           365               Fine particles (PM 2.5)
# 77        549803           375                Nitrogen dioxide (NO2)
# 88        823284           365               Fine particles (PM 2.5)
# 176       412469           375                Nitrogen dioxide (NO2)
# ...          ...           ...                                   ...
# 17892     315652           647     Outdoor Air Toxics - Formaldehyde
# 17921     602746           375                Nitrogen dioxide (NO2)
# 17922     825753           375                Nitrogen dioxide (NO2)
# 17988     151685           644  Annual vehicle miles traveled (cars)
# 18022     816872           643         Annual vehicle miles traveled
#
#                             Measure     Measure Info Geo Type Name  \
# 68                             Mean           mcg/m3         UHF42
# 69                             Mean           mcg/m3         UHF42
# 77                             Mean              ppb         UHF42
# 88                             Mean           mcg/m3         UHF42
# 176                            Mean              ppb         UHF42
# ...                             ...              ...           ...
# 17892  Annual average concentration           Âµg/m3         UHF42
# 17921                          Mean              ppb         UHF42
# 17922                          Mean              ppb         UHF42
# 17988                 Million miles  per square mile         UHF42
# 18022                 Million miles  per square mile         UHF42
#
#        Geo Join ID                 Place          Time Period  Start_Date  \
# 68           208.0  Canarsie - Flatlands          Summer 2021  06-01-2021
# 69           208.0  Canarsie - Flatlands  Annual Average 2017  01-01-2017
# 77           208.0  Canarsie - Flatlands  Annual Average 2017  01-01-2017
# 88           208.0  Canarsie - Flatlands       Winter 2021-22  12-01-2021
# 176          208.0  Canarsie - Flatlands       Winter 2015-16  12-01-2015
# ...            ...                   ...                  ...         ...
# 17892        208.0  Canarsie - Flatlands                 2011  01-01-2011
# 17921        208.0  Canarsie - Flatlands       Winter 2017-18  12-01-2017
# 17922        208.0  Canarsie - Flatlands  Annual Average 2022  01-01-2022
# 17988        208.0  Canarsie - Flatlands                 2005  01-01-2005
# 18022        208.0  Canarsie - Flatlands                 2010  01-01-2010
#
#        Data Value
# 68            8.0
# 69            7.0
# 77           15.6
# 88            6.4
# 176          20.9
# ...           ...
# 17892         1.8
# 17921        20.5
# 17922        13.4
# 17988        34.3
# 18022        43.4
#
# [269 rows x 11 columns]
# Central Harlem (CD10)
#        Unique ID  Indicator ID                                  Name  \
# 223       547627           365               Fine particles (PM 2.5)
# 932       412685           375                Nitrogen dioxide (NO2)
# 1779      410995           365               Fine particles (PM 2.5)
# 1793      412687           375                Nitrogen dioxide (NO2)
# 2561      167695           375                Nitrogen dioxide (NO2)
# ...          ...           ...                                   ...
# 14555     823195           365               Fine particles (PM 2.5)
# 15114     227577           646          Outdoor Air Toxics - Benzene
# 16341     643576           375                Nitrogen dioxide (NO2)
# 16342     825821           375                Nitrogen dioxide (NO2)
# 17413     154510           644  Annual vehicle miles traveled (cars)
#
#                             Measure     Measure Info Geo Type Name  \
# 223                            Mean           mcg/m3            CD
# 932                            Mean              ppb            CD
# 1779                           Mean           mcg/m3            CD
# 1793                           Mean              ppb            CD
# 2561                           Mean              ppb            CD
# ...                             ...              ...           ...
# 14555                          Mean           mcg/m3            CD
# 15114  Annual average concentration           Âµg/m3            CD
# 16341                          Mean              ppb            CD
# 16342                          Mean              ppb            CD
# 17413                 Million miles  per square mile            CD
#
#        Geo Join ID                  Place          Time Period  Start_Date  \
# 223          110.0  Central Harlem (CD10)  Annual Average 2017  01-01-2017
# 932          110.0  Central Harlem (CD10)       Winter 2015-16  12-01-2015
# 1779         110.0  Central Harlem (CD10)  Annual Average 2016  12/31/2015
# 1793         110.0  Central Harlem (CD10)  Annual Average 2016  12/31/2015
# 2561         110.0  Central Harlem (CD10)  Annual Average 2012  12-01-2011
# ...            ...                    ...                  ...         ...
# 14555        110.0  Central Harlem (CD10)  Annual Average 2022  01-01-2022
# 15114        110.0  Central Harlem (CD10)                 2011  01-01-2011
# 16341        110.0  Central Harlem (CD10)  Annual Average 2019  01-01-2019
# 16342        110.0  Central Harlem (CD10)  Annual Average 2022  01-01-2022
# 17413        110.0  Central Harlem (CD10)                 2005  01-01-2005
#
#        Data Value
# 223           7.9
# 932          25.8
# 1779          7.9
# 1793         22.3
# 2561         25.9
# ...           ...
# 14555         6.2
# 15114         2.1
# 16341        19.8
# 16342        16.8
# 17413        61.5
#
# [110 rows x 11 columns]
# Central Harlem - Morningside Heights
#        Unique ID  Indicator ID                                   Name  \
# 364       177956           365                Fine particles (PM 2.5)
# 368       130416           640  Boiler Emissions- Total SO2 Emissions
# 376       176696           375                 Nitrogen dioxide (NO2)
# 381       410794           365                Fine particles (PM 2.5)
# 383       605720           365                Fine particles (PM 2.5)
# ...          ...           ...                                    ...
# 17885     667406           375                 Nitrogen dioxide (NO2)
# 17905     667405           375                 Nitrogen dioxide (NO2)
# 17906     221885           386                             Ozone (O3)
# 17915     549935           375                 Nitrogen dioxide (NO2)
# 17939     221888           386                             Ozone (O3)
#
#               Measure Measure Info Geo Type Name  Geo Join ID  \
# 364              Mean       mcg/m3         UHF42        302.0
# 368    Number per km2       number         UHF42        302.0
# 376              Mean          ppb         UHF42        302.0
# 381              Mean       mcg/m3         UHF42        302.0
# 383              Mean       mcg/m3         UHF42        302.0
# ...               ...          ...           ...          ...
# 17885            Mean          ppb         UHF34        302.0
# 17905            Mean          ppb         UHF34        302.0
# 17906            Mean          ppb         UHF34        302.0
# 17915            Mean          ppb         UHF34        302.0
# 17939            Mean          ppb         UHF34        302.0
#
#                                       Place          Time Period  Start_Date  \
# 364    Central Harlem - Morningside Heights          Summer 2013  06-01-2013
# 368    Central Harlem - Morningside Heights                 2013  01-01-2013
# 376    Central Harlem - Morningside Heights  Annual Average 2013  12-01-2012
# 381    Central Harlem - Morningside Heights  Annual Average 2016  12/31/2015
# 383    Central Harlem - Morningside Heights  Annual Average 2018  01-01-2018
# ...                                     ...                  ...         ...
# 17885  Central Harlem - Morningside Heights       Winter 2019-20  12-01-2019
# 17905  Central Harlem - Morningside Heights  Annual Average 2020  01-01-2020
# 17906  Central Harlem - Morningside Heights          Summer 2009  06-01-2009
# 17915  Central Harlem - Morningside Heights  Annual Average 2017  01-01-2017
# 17939  Central Harlem - Morningside Heights          Summer 2012  06-01-2012
#
#        Data Value
# 364          10.8
# 368          15.7
# 376          25.4
# 381           8.0
# 383           7.5
# ...           ...
# 17885        26.6
# 17905        19.0
# 17906        21.5
# 17915        22.6
# 17939        31.7
#
# [269 rows x 11 columns]
# Chelsea - Clinton
#        Unique ID  Indicator ID  \
# 357       179804           640
# 360       178548           365
# 373       823257           365
# 375       605732           365
# 377       740964           375
# ...          ...           ...
# 14881     823255           365
# 14979     628508           657
# 16851     825726           375
# 17531     151694           644
# 17532     151646           643
#
#                                                   Name  \
# 357              Boiler Emissions- Total SO2 Emissions
# 360                            Fine particles (PM 2.5)
# 373                            Fine particles (PM 2.5)
# 375                            Fine particles (PM 2.5)
# 377                             Nitrogen dioxide (NO2)
# ...                                                ...
# 14881                          Fine particles (PM 2.5)
# 14979  Asthma emergency department visits due to PM2.5
# 16851                           Nitrogen dioxide (NO2)
# 17531             Annual vehicle miles traveled (cars)
# 17532                    Annual vehicle miles traveled
#
#                                Measure        Measure Info Geo Type Name  \
# 357                     Number per km2              number         UHF42
# 360                               Mean              mcg/m3         UHF42
# 373                               Mean              mcg/m3         UHF42
# 375                               Mean              mcg/m3         UHF42
# 377                               Mean                 ppb         UHF42
# ...                                ...                 ...           ...
# 14881                             Mean              mcg/m3         UHF42
# 14979  Estimated annual rate (age 18+)  per 100,000 adults         UHF42
# 16851                             Mean                 ppb         UHF42
# 17531                    Million miles     per square mile         UHF42
# 17532                    Million miles     per square mile         UHF42
#
#        Geo Join ID              Place          Time Period  Start_Date  \
# 357          306.0  Chelsea - Clinton                 2015  01-01-2015
# 360          306.0  Chelsea - Clinton  Annual Average 2012  12-01-2011
# 373          306.0  Chelsea - Clinton       Winter 2021-22  12-01-2021
# 375          306.0  Chelsea - Clinton  Annual Average 2018  01-01-2018
# 377          306.0  Chelsea - Clinton  Annual Average 2021  01-01-2021
# ...            ...                ...                  ...         ...
# 14881        306.0  Chelsea - Clinton  Annual Average 2022  01-01-2022
# 14979        306.0  Chelsea - Clinton            2015-2017  01-01-2015
# 16851        306.0  Chelsea - Clinton  Annual Average 2022  01-01-2022
# 17531        306.0  Chelsea - Clinton                 2005  01-01-2005
# 17532        306.0  Chelsea - Clinton                 2005  01-01-2005
#
#        Data Value
# 357          36.4
# 360          12.4
# 373           9.3
# 375          10.0
# 377          23.3
# ...           ...
# 14881         8.4
# 14979        20.4
# 16851        22.9
# 17531       114.9
# 17532       126.0
#
# [170 rows x 11 columns]
# Chelsea-Village
#        Unique ID  Indicator ID                     Name Measure Measure Info  \
# 12722     334164           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 12723     547579           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 12765     412639           375   Nitrogen dioxide (NO2)    Mean          ppb
# 12766     602912           375   Nitrogen dioxide (NO2)    Mean          ppb
# 12905     336702           375   Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                      ...     ...          ...
# 17180     211580           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17181     643528           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17182     602914           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17185     171587           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17296     825869           375   Nitrogen dioxide (NO2)    Mean          ppb
#
#       Geo Type Name  Geo Join ID            Place          Time Period  \
# 12722         UHF34     306308.0  Chelsea-Village       Winter 2014-15
# 12723         UHF34     306308.0  Chelsea-Village  Annual Average 2017
# 12765         UHF34     306308.0  Chelsea-Village  Annual Average 2016
# 12766         UHF34     306308.0  Chelsea-Village  Annual Average 2018
# 12905         UHF34     306308.0  Chelsea-Village       Winter 2014-15
# ...             ...          ...              ...                  ...
# 17180         UHF34     306308.0  Chelsea-Village       Winter 2013-14
# 17181         UHF34     306308.0  Chelsea-Village  Annual Average 2019
# 17182         UHF34     306308.0  Chelsea-Village       Winter 2017-18
# 17185         UHF34     306308.0  Chelsea-Village       Winter 2008-09
# 17296         UHF34     306308.0  Chelsea-Village  Annual Average 2022
#
#        Start_Date  Data Value
# 12722  12-01-2014        11.7
# 12723  01-01-2017         9.6
# 12765  12/31/2015        27.6
# 12766  01-01-2018        26.6
# 12905  12-01-2014        31.5
# ...           ...         ...
# 17180  12-01-2013        35.9
# 17181  01-01-2019        25.2
# 17182  12-01-2017        31.1
# 17185  12-01-2008        42.7
# 17296  01-01-2022        22.1
#
# [99 rows x 11 columns]
# Clinton and Chelsea (CD4)
#        Unique ID  Indicator ID                                    Name  \
# 873       336731           375                  Nitrogen dioxide (NO2)
# 874       667538           375                  Nitrogen dioxide (NO2)
# 1139      334194           365                 Fine particles (PM 2.5)
# 1149      643560           375                  Nitrogen dioxide (NO2)
# 1155      336730           375                  Nitrogen dioxide (NO2)
# ...          ...           ...                                     ...
# 16490     213226           375                  Nitrogen dioxide (NO2)
# 17262     602944           375                  Nitrogen dioxide (NO2)
# 17481     154445           645  Annual vehicle miles traveled (trucks)
# 17589     154504           644    Annual vehicle miles traveled (cars)
# 17594     816808           643           Annual vehicle miles traveled
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 873             Mean              ppb            CD        104.0
# 874             Mean              ppb            CD        104.0
# 1139            Mean           mcg/m3            CD        104.0
# 1149            Mean              ppb            CD        104.0
# 1155            Mean              ppb            CD        104.0
# ...              ...              ...           ...          ...
# 16490           Mean              ppb            CD        104.0
# 17262           Mean              ppb            CD        104.0
# 17481  Million miles  per square mile            CD        104.0
# 17589  Million miles  per square mile            CD        104.0
# 17594  Million miles  per square mile            CD        104.0
#
#                            Place          Time Period  Start_Date  Data Value
# 873    Clinton and Chelsea (CD4)          Summer 2015  06-01-2015        23.4
# 874    Clinton and Chelsea (CD4)       Winter 2019-20  12-01-2019        32.1
# 1139   Clinton and Chelsea (CD4)       Winter 2014-15  12-01-2014        11.5
# 1149   Clinton and Chelsea (CD4)       Winter 2018-19  12-01-2018        28.3
# 1155   Clinton and Chelsea (CD4)  Annual Average 2015  01-01-2015        27.3
# ...                          ...                  ...         ...         ...
# 16490  Clinton and Chelsea (CD4)       Winter 2013-14  12-01-2013        34.8
# 17262  Clinton and Chelsea (CD4)       Winter 2017-18  12-01-2017        30.2
# 17481  Clinton and Chelsea (CD4)                 2005  01-01-2005         7.8
# 17589  Clinton and Chelsea (CD4)                 2005  01-01-2005       111.0
# 17594  Clinton and Chelsea (CD4)                 2010  01-01-2010       125.5
#
# [110 rows x 11 columns]
# Coney Island (CD13)
#        Unique ID  Indicator ID                                  Name  \
# 1233      650002           365               Fine particles (PM 2.5)
# 1234      823511           365               Fine particles (PM 2.5)
# 1235      334293           365               Fine particles (PM 2.5)
# 1236      826334           375                Nitrogen dioxide (NO2)
# 1247      216495           386                            Ozone (O3)
# ...          ...           ...                                   ...
# 17453     154537           644  Annual vehicle miles traveled (cars)
# 17458     817083           644  Annual vehicle miles traveled (cars)
# 17459     817084           644  Annual vehicle miles traveled (cars)
# 17460     816741           643         Annual vehicle miles traveled
# 17583     816742           643         Annual vehicle miles traveled
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 1233            Mean           mcg/m3            CD        313.0
# 1234            Mean           mcg/m3            CD        313.0
# 1235            Mean           mcg/m3            CD        313.0
# 1236            Mean              ppb            CD        313.0
# 1247            Mean              ppb            CD        313.0
# ...              ...              ...           ...          ...
# 17453  Million miles  per square mile            CD        313.0
# 17458  Million miles  per square mile            CD        313.0
# 17459  Million miles  per square mile            CD        313.0
# 17460  Million miles  per square mile            CD        313.0
# 17583  Million miles  per square mile            CD        313.0
#
#                      Place          Time Period  Start_Date  Data Value
# 1233   Coney Island (CD13)  Annual Average 2019  01-01-2019         6.0
# 1234   Coney Island (CD13)  Annual Average 2022  01-01-2022         5.4
# 1235   Coney Island (CD13)       Winter 2014-15  12-01-2014         8.0
# 1236   Coney Island (CD13)  Annual Average 2022  01-01-2022        12.8
# 1247   Coney Island (CD13)          Summer 2010  06-01-2010        37.4
# ...                    ...                  ...         ...         ...
# 17453  Coney Island (CD13)                 2005  01-01-2005        30.5
# 17458  Coney Island (CD13)                 2010  01-01-2010        42.8
# 17459  Coney Island (CD13)                 2019  01-01-2019        39.3
# 17460  Coney Island (CD13)                 2019  01-01-2019        41.0
# 17583  Coney Island (CD13)                 2010  01-01-2010        43.9
#
# [110 rows x 11 columns]
# Coney Island - Sheepshead Bay
#        Unique ID  Indicator ID                                    Name  \
# 11        178583           365                 Fine particles (PM 2.5)
# 13        547417           365                 Fine particles (PM 2.5)
# 16        130413           640   Boiler Emissions- Total SO2 Emissions
# 231       176651           375                  Nitrogen dioxide (NO2)
# 241       669790           365                 Fine particles (PM 2.5)
# ...          ...           ...                                     ...
# 16947     602869           375                  Nitrogen dioxide (NO2)
# 16959     173102           365                 Fine particles (PM 2.5)
# 16960     605830           365                 Fine particles (PM 2.5)
# 17303     151735           645  Annual vehicle miles traveled (trucks)
# 17308     151687           644    Annual vehicle miles traveled (cars)
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# 11               Mean           mcg/m3         UHF42        210.0
# 13               Mean           mcg/m3         UHF42        210.0
# 16     Number per km2           number         UHF42        210.0
# 231              Mean              ppb         UHF42        210.0
# 241              Mean           mcg/m3         UHF42        210.0
# ...               ...              ...           ...          ...
# 16947            Mean              ppb         UHF34        210.0
# 16959            Mean           mcg/m3         UHF34        210.0
# 16960            Mean           mcg/m3         UHF34        210.0
# 17303   Million miles  per square mile         UHF42        210.0
# 17308   Million miles  per square mile         UHF42        210.0
#
#                                Place          Time Period  Start_Date  \
# 11     Coney Island - Sheepshead Bay  Annual Average 2013  12-01-2012
# 13     Coney Island - Sheepshead Bay  Annual Average 2017  01-01-2017
# 16     Coney Island - Sheepshead Bay                 2013  01-01-2013
# 231    Coney Island - Sheepshead Bay  Annual Average 2012  12-01-2011
# 241    Coney Island - Sheepshead Bay  Annual Average 2020  01-01-2020
# ...                              ...                  ...         ...
# 16947  Coney Island - Sheepshead Bay       Winter 2017-18  12-01-2017
# 16959  Coney Island - Sheepshead Bay       Winter 2008-09  12-01-2008
# 16960  Coney Island - Sheepshead Bay       Winter 2017-18  12-01-2017
# 17303  Coney Island - Sheepshead Bay                 2005  01-01-2005
# 17308  Coney Island - Sheepshead Bay                 2005  01-01-2005
#
#        Data Value
# 11            8.1
# 13            6.8
# 16            0.9
# 231          17.2
# 241           5.7
# ...           ...
# 16947        19.7
# 16959        11.1
# 16960         7.8
# 17303         1.7
# 17308        33.7
#
# [269 rows x 11 columns]
# Crotona -Tremont
#        Unique ID  Indicator ID                                    Name  \
# 293       178529           365                 Fine particles (PM 2.5)
# 298       823314           365                 Fine particles (PM 2.5)
# 321       740907           375                  Nitrogen dioxide (NO2)
# 613       177941           365                 Fine particles (PM 2.5)
# 618       740906           375                  Nitrogen dioxide (NO2)
# ...          ...           ...                                     ...
# 16496     212672           365                 Fine particles (PM 2.5)
# 16651     825783           375                  Nitrogen dioxide (NO2)
# 16666     643330           375                  Nitrogen dioxide (NO2)
# 17488     151723           645  Annual vehicle miles traveled (trucks)
# 17499     151675           644    Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 293             Mean           mcg/m3         UHF42        105.0
# 298             Mean           mcg/m3         UHF42        105.0
# 321             Mean              ppb         UHF42        105.0
# 613             Mean           mcg/m3         UHF42        105.0
# 618             Mean              ppb         UHF42        105.0
# ...              ...              ...           ...          ...
# 16496           Mean           mcg/m3         UHF42        105.0
# 16651           Mean              ppb         UHF42        105.0
# 16666           Mean              ppb         UHF42        105.0
# 17488  Million miles  per square mile         UHF42        105.0
# 17499  Million miles  per square mile         UHF42        105.0
#
#                   Place          Time Period  Start_Date  Data Value
# 293    Crotona -Tremont  Annual Average 2012  12-01-2011        10.2
# 298    Crotona -Tremont       Winter 2021-22  12-01-2021         7.3
# 321    Crotona -Tremont  Annual Average 2021  01-01-2021        17.6
# 613    Crotona -Tremont          Summer 2013  06-01-2013        10.9
# 618    Crotona -Tremont          Summer 2021  06-01-2021        13.8
# ...                 ...                  ...         ...         ...
# 16496  Crotona -Tremont       Winter 2013-14  12-01-2013        13.1
# 16651  Crotona -Tremont  Annual Average 2022  01-01-2022        17.2
# 16666  Crotona -Tremont  Annual Average 2019  01-01-2019        17.6
# 17488  Crotona -Tremont                 2005  01-01-2005         5.3
# 17499  Crotona -Tremont                 2005  01-01-2005        74.1
#
# [170 rows x 11 columns]
# Crown Heights and Prospect Heights (CD8)
#        Unique ID  Indicator ID                                    Name  \
# 877       166006           375                  Nitrogen dioxide (NO2)
# 892       168543           365                 Fine particles (PM 2.5)
# 1138      169310           365                 Fine particles (PM 2.5)
# 1143      167599           375                  Nitrogen dioxide (NO2)
# 1144      667706           375                  Nitrogen dioxide (NO2)
# ...          ...           ...                                     ...
# 17475     817287           645  Annual vehicle miles traveled (trucks)
# 17476     817288           645  Annual vehicle miles traveled (trucks)
# 17483     154473           645  Annual vehicle miles traveled (trucks)
# 17496     154532           644    Annual vehicle miles traveled (cars)
# 17593     817074           644    Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 877             Mean              ppb            CD        308.0
# 892             Mean           mcg/m3            CD        308.0
# 1138            Mean           mcg/m3            CD        308.0
# 1143            Mean              ppb            CD        308.0
# 1144            Mean              ppb            CD        308.0
# ...              ...              ...           ...          ...
# 17475  Million miles  per square mile            CD        308.0
# 17476  Million miles  per square mile            CD        308.0
# 17483  Million miles  per square mile            CD        308.0
# 17496  Million miles  per square mile            CD        308.0
# 17593  Million miles  per square mile            CD        308.0
#
#                                           Place          Time Period  \
# 877    Crown Heights and Prospect Heights (CD8)       Winter 2012-13
# 892    Crown Heights and Prospect Heights (CD8)       Winter 2010-11
# 1138   Crown Heights and Prospect Heights (CD8)          Summer 2009
# 1143   Crown Heights and Prospect Heights (CD8)  Annual Average 2010
# 1144   Crown Heights and Prospect Heights (CD8)       Winter 2019-20
# ...                                         ...                  ...
# 17475  Crown Heights and Prospect Heights (CD8)                 2010
# 17476  Crown Heights and Prospect Heights (CD8)                 2019
# 17483  Crown Heights and Prospect Heights (CD8)                 2005
# 17496  Crown Heights and Prospect Heights (CD8)                 2005
# 17593  Crown Heights and Prospect Heights (CD8)                 2019
#
#        Start_Date  Data Value
# 877    12-01-2012        27.6
# 892    12-01-2010        12.9
# 1138   06-01-2009        11.0
# 1143   12-01-2009        25.9
# 1144   12-01-2019        28.0
# ...           ...         ...
# 17475  01-01-2010         2.1
# 17476  01-01-2019         3.1
# 17483  01-01-2005         2.6
# 17496  01-01-2005        69.2
# 17593  01-01-2019        82.7
#
# [110 rows x 11 columns]
# Downtown - Heights - Slope
#        Unique ID  Indicator ID                                   Name  \
# 89        334095           365                Fine particles (PM 2.5)
# 90        547510           365                Fine particles (PM 2.5)
# 358       179789           640  Boiler Emissions- Total SO2 Emissions
# 359       823301           365                Fine particles (PM 2.5)
# 362       823302           365                Fine particles (PM 2.5)
# ...          ...           ...                                    ...
# 17901     823438           365                Fine particles (PM 2.5)
# 17936     827078           386                             Ozone (O3)
# 17937     825961           375                 Nitrogen dioxide (NO2)
# 17940     825962           375                 Nitrogen dioxide (NO2)
# 17975     825960           375                 Nitrogen dioxide (NO2)
#
#               Measure Measure Info Geo Type Name  Geo Join ID  \
# 89               Mean       mcg/m3         UHF34        202.0
# 90               Mean       mcg/m3         UHF34        202.0
# 358    Number per km2       number         UHF42        202.0
# 359              Mean       mcg/m3         UHF42        202.0
# 362              Mean       mcg/m3         UHF42        202.0
# ...               ...          ...           ...          ...
# 17901            Mean       mcg/m3         UHF34        202.0
# 17936            Mean          ppb         UHF34        202.0
# 17937            Mean          ppb         UHF34        202.0
# 17940            Mean          ppb         UHF34        202.0
# 17975            Mean          ppb         UHF34        202.0
#
#                             Place          Time Period  Start_Date  Data Value
# 89     Downtown - Heights - Slope       Winter 2014-15  12-01-2014        10.1
# 90     Downtown - Heights - Slope  Annual Average 2017  01-01-2017         8.4
# 358    Downtown - Heights - Slope                 2015  01-01-2015         1.2
# 359    Downtown - Heights - Slope          Summer 2022  06-01-2022         6.9
# 362    Downtown - Heights - Slope       Winter 2021-22  12-01-2021         7.4
# ...                           ...                  ...         ...         ...
# 17901  Downtown - Heights - Slope  Annual Average 2022  01-01-2022         6.4
# 17936  Downtown - Heights - Slope          Summer 2022  06-01-2022        32.3
# 17937  Downtown - Heights - Slope          Summer 2022  06-01-2022        13.4
# 17940  Downtown - Heights - Slope       Winter 2021-22  12-01-2021        23.3
# 17975  Downtown - Heights - Slope  Annual Average 2022  01-01-2022        18.0
#
# [269 rows x 11 columns]
# East Flatbush (CD17)
#        Unique ID  Indicator ID                                    Name  \
# 3718      411086           365                 Fine particles (PM 2.5)
# 3725      412111           386                              Ozone (O3)
# 3729      412778           375                  Nitrogen dioxide (NO2)
# 3730      741244           375                  Nitrogen dioxide (NO2)
# 3735      336843           375                  Nitrogen dioxide (NO2)
# ...          ...           ...                                     ...
# 17781     213263           375                  Nitrogen dioxide (NO2)
# 17782     826346           375                  Nitrogen dioxide (NO2)
# 17925     643669           375                  Nitrogen dioxide (NO2)
# 17971     154482           645  Annual vehicle miles traveled (trucks)
# 17998     154541           644    Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 3718            Mean           mcg/m3            CD        317.0
# 3725            Mean              ppb            CD        317.0
# 3729            Mean              ppb            CD        317.0
# 3730            Mean              ppb            CD        317.0
# 3735            Mean              ppb            CD        317.0
# ...              ...              ...           ...          ...
# 17781           Mean              ppb            CD        317.0
# 17782           Mean              ppb            CD        317.0
# 17925           Mean              ppb            CD        317.0
# 17971  Million miles  per square mile            CD        317.0
# 17998  Million miles  per square mile            CD        317.0
#
#                       Place          Time Period  Start_Date  Data Value
# 3718   East Flatbush (CD17)       Winter 2015-16  12-01-2015         8.5
# 3725   East Flatbush (CD17)          Summer 2016  06-01-2016        33.9
# 3729   East Flatbush (CD17)       Winter 2015-16  12-01-2015        23.9
# 3730   East Flatbush (CD17)       Winter 2020-21  12-01-2020        22.9
# 3735   East Flatbush (CD17)       Winter 2014-15  12-01-2014        25.8
# ...                     ...                  ...         ...         ...
# 17781  East Flatbush (CD17)       Winter 2013-14  12-01-2013        28.4
# 17782  East Flatbush (CD17)  Annual Average 2022  01-01-2022        15.3
# 17925  East Flatbush (CD17)  Annual Average 2019  01-01-2019        16.4
# 17971  East Flatbush (CD17)                 2005  01-01-2005         3.3
# 17998  East Flatbush (CD17)                 2005  01-01-2005        95.2
#
# [110 rows x 11 columns]
# East Flatbush - Flatbush
#        Unique ID  Indicator ID  \
# 175       175892           375
# 181       175934           375
# 189       131424           648
# 604       175262           375
# 605       602743           375
# ...          ...           ...
# 17807     151588           661
# 17826     825756           375
# 17847     131472           651
# 17870     212303           375
# 17992     151684           644
#
#                                                     Name  \
# 175                               Nitrogen dioxide (NO2)
# 181                               Nitrogen dioxide (NO2)
# 189      Asthma emergency department visits due to PM2.5
# 604                               Nitrogen dioxide (NO2)
# 605                               Nitrogen dioxide (NO2)
# ...                                                  ...
# 17807               Asthma hospitalizations due to Ozone
# 17826                             Nitrogen dioxide (NO2)
# 17847  Cardiovascular hospitalizations due to PM2.5 (...
# 17870                             Nitrogen dioxide (NO2)
# 17992               Annual vehicle miles traveled (cars)
#
#                                     Measure          Measure Info  \
# 175                                    Mean                   ppb
# 181                                    Mean                   ppb
# 189    Estimated annual rate (under age 18)  per 100,000 children
# 604                                    Mean                   ppb
# 605                                    Mean                   ppb
# ...                                     ...                   ...
# 17807       Estimated annual rate (age 18+)    per 100,000 adults
# 17826                                  Mean                   ppb
# 17847                 Estimated annual rate    per 100,000 adults
# 17870                                  Mean                   ppb
# 17992                         Million miles       per square mile
#
#       Geo Type Name  Geo Join ID                     Place  \
# 175           UHF42        207.0  East Flatbush - Flatbush
# 181           UHF42        207.0  East Flatbush - Flatbush
# 189           UHF42        207.0  East Flatbush - Flatbush
# 604           UHF42        207.0  East Flatbush - Flatbush
# 605           UHF42        207.0  East Flatbush - Flatbush
# ...             ...          ...                       ...
# 17807         UHF42        207.0  East Flatbush - Flatbush
# 17826         UHF42        207.0  East Flatbush - Flatbush
# 17847         UHF42        207.0  East Flatbush - Flatbush
# 17870         UHF42        207.0  East Flatbush - Flatbush
# 17992         UHF42        207.0  East Flatbush - Flatbush
#
#                Time Period  Start_Date  Data Value
# 175            Summer 2009  06-01-2009        21.4
# 181            Summer 2010  06-01-2010        19.0
# 189              2009-2011  01-01-2009       115.8
# 604         Winter 2008-09  12-01-2008        30.5
# 605         Winter 2017-18  12-01-2017        24.3
# ...                    ...         ...         ...
# 17807            2009-2011  01-01-2009         7.3
# 17826  Annual Average 2022  01-01-2022        15.0
# 17847            2009-2011  01-01-2009        18.5
# 17870       Winter 2013-14  12-01-2013        28.3
# 17992                 2005  01-01-2005        71.9
#
# [269 rows x 11 columns]
# East Harlem
#        Unique ID  Indicator ID                                   Name  \
# 304       742224           365                Fine particles (PM 2.5)
# 306       130417           640  Boiler Emissions- Total SO2 Emissions
# 310       742223           365                Fine particles (PM 2.5)
# 619       549821           375                 Nitrogen dioxide (NO2)
# 641       412488           375                 Nitrogen dioxide (NO2)
# ...          ...           ...                                    ...
# 17171     412604           375                 Nitrogen dioxide (NO2)
# 17266     602764           375                 Nitrogen dioxide (NO2)
# 17267     825735           375                 Nitrogen dioxide (NO2)
# 17500     151691           644   Annual vehicle miles traveled (cars)
# 17600     816860           643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# 304              Mean           mcg/m3         UHF42        303.0
# 306    Number per km2           number         UHF42        303.0
# 310              Mean           mcg/m3         UHF42        303.0
# 619              Mean              ppb         UHF42        303.0
# 641              Mean              ppb         UHF42        303.0
# ...               ...              ...           ...          ...
# 17171            Mean              ppb         UHF34        303.0
# 17266            Mean              ppb         UHF42        303.0
# 17267            Mean              ppb         UHF42        303.0
# 17500   Million miles  per square mile         UHF42        303.0
# 17600   Million miles  per square mile         UHF42        303.0
#
#              Place          Time Period  Start_Date  Data Value
# 304    East Harlem  Annual Average 2021  01-01-2021         6.8
# 306    East Harlem                 2013  01-01-2013        11.6
# 310    East Harlem          Summer 2021  06-01-2021         8.7
# 619    East Harlem  Annual Average 2017  01-01-2017        22.4
# 641    East Harlem          Summer 2016  06-01-2016        17.8
# ...            ...                  ...         ...         ...
# 17171  East Harlem       Winter 2015-16  12-01-2015        26.0
# 17266  East Harlem       Winter 2017-18  12-01-2017        26.8
# 17267  East Harlem  Annual Average 2022  01-01-2022        16.7
# 17500  East Harlem                 2005  01-01-2005       102.5
# 17600  East Harlem                 2010  01-01-2010       146.0
#
# [269 rows x 11 columns]
# East Harlem (CD11)
#        Unique ID  Indicator ID                                    Name  \
# 476       170410           365                 Fine particles (PM 2.5)
# 850       605924           365                 Fine particles (PM 2.5)
# 851       823194           365                 Fine particles (PM 2.5)
# 860       602963           375                  Nitrogen dioxide (NO2)
# 861       825820           375                  Nitrogen dioxide (NO2)
# ...          ...           ...                                     ...
# 17089     817031           644    Annual vehicle miles traveled (cars)
# 17536     154452           645  Annual vehicle miles traveled (trucks)
# 17546     154511           644    Annual vehicle miles traveled (cars)
# 17555     816794           643           Annual vehicle miles traveled
# 17556     816793           643           Annual vehicle miles traveled
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 476             Mean           mcg/m3            CD        111.0
# 850             Mean           mcg/m3            CD        111.0
# 851             Mean           mcg/m3            CD        111.0
# 860             Mean              ppb            CD        111.0
# 861             Mean              ppb            CD        111.0
# ...              ...              ...           ...          ...
# 17089  Million miles  per square mile            CD        111.0
# 17536  Million miles  per square mile            CD        111.0
# 17546  Million miles  per square mile            CD        111.0
# 17555  Million miles  per square mile            CD        111.0
# 17556  Million miles  per square mile            CD        111.0
#
#                     Place          Time Period  Start_Date  Data Value
# 476    East Harlem (CD11)  Annual Average 2013  12-01-2012         9.7
# 850    East Harlem (CD11)  Annual Average 2018  01-01-2018         7.4
# 851    East Harlem (CD11)       Winter 2021-22  12-01-2021         7.0
# 860    East Harlem (CD11)  Annual Average 2018  01-01-2018        20.9
# 861    East Harlem (CD11)       Winter 2021-22  12-01-2021        21.6
# ...                   ...                  ...         ...         ...
# 17089  East Harlem (CD11)                 2010  01-01-2010       142.5
# 17536  East Harlem (CD11)                 2005  01-01-2005         4.9
# 17546  East Harlem (CD11)                 2005  01-01-2005       104.8
# 17555  East Harlem (CD11)                 2010  01-01-2010       151.6
# 17556  East Harlem (CD11)                 2019  01-01-2019       152.6
#
# [110 rows x 11 columns]
# East New York
#        Unique ID  Indicator ID                                    Name  \
# 49        605693           365                 Fine particles (PM 2.5)
# 50        742193           365                 Fine particles (PM 2.5)
# 51        177905           365                 Fine particles (PM 2.5)
# 60        410767           365                 Fine particles (PM 2.5)
# 64        823296           365                 Fine particles (PM 2.5)
# ...          ...           ...                                     ...
# 17277     211559           375                  Nitrogen dioxide (NO2)
# 17278     602851           375                  Nitrogen dioxide (NO2)
# 17384     151729           645  Annual vehicle miles traveled (trucks)
# 17386     151681           644    Annual vehicle miles traveled (cars)
# 17575     816879           643           Annual vehicle miles traveled
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 49              Mean           mcg/m3         UHF42        204.0
# 50              Mean           mcg/m3         UHF42        204.0
# 51              Mean           mcg/m3         UHF42        204.0
# 60              Mean           mcg/m3         UHF42        204.0
# 64              Mean           mcg/m3         UHF42        204.0
# ...              ...              ...           ...          ...
# 17277           Mean              ppb         UHF34        204.0
# 17278           Mean              ppb         UHF34        204.0
# 17384  Million miles  per square mile         UHF42        204.0
# 17386  Million miles  per square mile         UHF42        204.0
# 17575  Million miles  per square mile         UHF42        204.0
#
#                Place          Time Period  Start_Date  Data Value
# 49     East New York  Annual Average 2018  01-01-2018         7.1
# 50     East New York          Summer 2021  06-01-2021         8.3
# 51     East New York          Summer 2012  06-01-2012         9.7
# 60     East New York  Annual Average 2016  12/31/2015         7.8
# 64     East New York       Winter 2021-22  12-01-2021         6.7
# ...              ...                  ...         ...         ...
# 17277  East New York       Winter 2013-14  12-01-2013        27.9
# 17278  East New York       Winter 2017-18  12-01-2017        24.5
# 17384  East New York                 2005  01-01-2005         6.4
# 17386  East New York                 2005  01-01-2005        48.8
# 17575  East New York                 2019  01-01-2019        55.4
#
# [269 rows x 11 columns]
# East New York and Starrett City (CD5)
#        Unique ID  Indicator ID                                  Name  \
# 488       168540           365               Fine particles (PM 2.5)
# 489       169307           365               Fine particles (PM 2.5)
# 490       605978           365               Fine particles (PM 2.5)
# 491       823485           365               Fine particles (PM 2.5)
# 494       334269           365               Fine particles (PM 2.5)
# ...          ...           ...                                   ...
# 14952     826046           375                Nitrogen dioxide (NO2)
# 16156     168422           365               Fine particles (PM 2.5)
# 16284     165767           375                Nitrogen dioxide (NO2)
# 17528     154588           643         Annual vehicle miles traveled
# 17605     154529           644  Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 488             Mean           mcg/m3            CD        305.0
# 489             Mean           mcg/m3            CD        305.0
# 490             Mean           mcg/m3            CD        305.0
# 491             Mean           mcg/m3            CD        305.0
# 494             Mean           mcg/m3            CD        305.0
# ...              ...              ...           ...          ...
# 14952           Mean              ppb            CD        305.0
# 16156           Mean           mcg/m3            CD        305.0
# ...
# 407                            Mean              ppb            CD
# 408                            Mean              ppb            CD
# 409                            Mean              ppb            CD
# 933                            Mean              ppb            CD
# ...                             ...              ...           ...
# 14543                          Mean              ppb            CD
# 14556                          Mean           mcg/m3            CD
# 15116  Annual average concentration           Âµg/m3            CD
# 16336                          Mean              ppb            CD
# 17400                 Million miles  per square mile            CD
#
#        Geo Join ID                                 Place          Time Period  \
# 224          112.0  Washington Heights and Inwood (CD12)  Annual Average 2021
# 407          112.0  Washington Heights and Inwood (CD12)       Winter 2010-11
# 408          112.0  Washington Heights and Inwood (CD12)          Summer 2009
# 409          112.0  Washington Heights and Inwood (CD12)  Annual Average 2013
# 933          112.0  Washington Heights and Inwood (CD12)       Winter 2020-21
# ...            ...                                   ...                  ...
# 14543        112.0  Washington Heights and Inwood (CD12)          Summer 2022
# 14556        112.0  Washington Heights and Inwood (CD12)  Annual Average 2019
# 15116        112.0  Washington Heights and Inwood (CD12)                 2011
# 16336        112.0  Washington Heights and Inwood (CD12)  Annual Average 2019
# 17400        112.0  Washington Heights and Inwood (CD12)                 2005
#
#        Start_Date  Data Value
# 224    01-01-2021         6.9
# 407    12-01-2010        30.0
# 408    06-01-2009        25.0
# 409    12-01-2012        22.3
# 933    12-01-2020        20.2
# ...           ...         ...
# 14543  06-01-2022        29.6
# 14556  01-01-2019         7.2
# 15116  01-01-2011         2.6
# 16336  01-01-2019        16.9
# 17400  01-01-2005        87.0
#
# [110 rows x 11 columns]
# West Queens
#        Unique ID  Indicator ID                     Name Measure Measure Info  \
# 450       410824           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 451       823239           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 454       825710           375   Nitrogen dioxide (NO2)    Mean          ppb
# 468       176538           375   Nitrogen dioxide (NO2)    Mean          ppb
# 469       176622           375   Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                      ...     ...          ...
# 17967     667429           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17968     336676           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17969     602888           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17983     602890           375   Nitrogen dioxide (NO2)    Mean          ppb
# 17984     643504           375   Nitrogen dioxide (NO2)    Mean          ppb
#
#       Geo Type Name  Geo Join ID        Place          Time Period  \
# 450           UHF42        402.0  West Queens  Annual Average 2016
# 451           UHF42        402.0  West Queens       Winter 2021-22
# 454           UHF42        402.0  West Queens       Winter 2021-22
# 468           UHF42        402.0  West Queens  Annual Average 2009
# 469           UHF42        402.0  West Queens  Annual Average 2011
# ...             ...          ...          ...                  ...
# 17967         UHF34        402.0  West Queens  Annual Average 2020
# 17968         UHF34        402.0  West Queens  Annual Average 2015
# 17969         UHF34        402.0  West Queens  Annual Average 2018
# 17983         UHF34        402.0  West Queens       Winter 2017-18
# 17984         UHF34        402.0  West Queens  Annual Average 2019
#
#        Start_Date  Data Value
# 450    12/31/2015         8.1
# 451    12-01-2021         7.1
# 454    12-01-2021        22.6
# 468    12-01-2008        25.8
# 469    12-01-2010        25.0
# ...           ...         ...
# 17967  01-01-2020        17.8
# 17968  01-01-2015        21.1
# 17969  01-01-2018        19.9
# 17983  12-01-2017        26.8
# 17984  01-01-2019        18.7
#
# [269 rows x 11 columns]
# Williamsbridge and Baychester (CD12)
#        Unique ID  Indicator ID                                  Name  \
# 126       169302           365               Fine particles (PM 2.5)
# 198       605963           365               Fine particles (PM 2.5)
# 205       547669           365               Fine particles (PM 2.5)
# 215       165998           375                Nitrogen dioxide (NO2)
# 225       168535           365               Fine particles (PM 2.5)
# ...          ...           ...                                   ...
# 14330     741193           375                Nitrogen dioxide (NO2)
# 14335     412094           386                            Ozone (O3)
# 14558     649963           365               Fine particles (PM 2.5)
# 16997     643618           375                Nitrogen dioxide (NO2)
# 17399     154524           644  Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 126             Mean           mcg/m3            CD        212.0
# 198             Mean           mcg/m3            CD        212.0
# 205             Mean           mcg/m3            CD        212.0
# 215             Mean              ppb            CD        212.0
# 225             Mean           mcg/m3            CD        212.0
# ...              ...              ...           ...          ...
# 14330           Mean              ppb            CD        212.0
# 14335           Mean              ppb            CD        212.0
# 14558           Mean           mcg/m3            CD        212.0
# 16997           Mean              ppb            CD        212.0
# 17399  Million miles  per square mile            CD        212.0
#
#                                       Place          Time Period  Start_Date  \
# 126    Williamsbridge and Baychester (CD12)          Summer 2009  06-01-2009
# 198    Williamsbridge and Baychester (CD12)  Annual Average 2018  01-01-2018
# 205    Williamsbridge and Baychester (CD12)  Annual Average 2017  01-01-2017
# 215    Williamsbridge and Baychester (CD12)       Winter 2012-13  12-01-2012
# 225    Williamsbridge and Baychester (CD12)       Winter 2010-11  12-01-2010
# ...                                     ...                  ...         ...
# 14330  Williamsbridge and Baychester (CD12)       Winter 2020-21  12-01-2020
# 14335  Williamsbridge and Baychester (CD12)          Summer 2016  06-01-2016
# 14558  Williamsbridge and Baychester (CD12)  Annual Average 2019  01-01-2019
# 16997  Williamsbridge and Baychester (CD12)  Annual Average 2019  01-01-2019
# 17399  Williamsbridge and Baychester (CD12)                 2005  01-01-2005
#
#        Data Value
# 126          10.2
# 198           7.0
# 205           7.4
# 215          22.0
# 225          13.4
# ...           ...
# 14330        18.8
# 14335        33.2
# 14558         6.7
# 16997        14.2
# 17399        39.7
#
# [110 rows x 11 columns]
# Williamsburg - Bushwick
#        Unique ID  Indicator ID                                  Name  \
# 34        178542           365               Fine particles (PM 2.5)
# 35        177912           365               Fine particles (PM 2.5)
# 36        177954           365               Fine particles (PM 2.5)
# 39        742215           365               Fine particles (PM 2.5)
# 45        823275           365               Fine particles (PM 2.5)
# ...          ...           ...                                   ...
# 16801     649831           365               Fine particles (PM 2.5)
# 16996     825912           375                Nitrogen dioxide (NO2)
# 17016     221876           386                            Ozone (O3)
# 17240     643486           375                Nitrogen dioxide (NO2)
# 17388     151688           644  Annual vehicle miles traveled (cars)
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 34              Mean           mcg/m3         UHF42        211.0
# 35              Mean           mcg/m3         UHF42        211.0
# 36              Mean           mcg/m3         UHF42        211.0
# 39              Mean           mcg/m3         UHF42        211.0
# 45              Mean           mcg/m3         UHF42        211.0
# ...              ...              ...           ...          ...
# 16801           Mean           mcg/m3         UHF34        211.0
# 16996           Mean              ppb         UHF34        211.0
# 17016           Mean              ppb         UHF34        211.0
# 17240           Mean              ppb         UHF34        211.0
# 17388  Million miles  per square mile         UHF42        211.0
#
#                          Place          Time Period  Start_Date  Data Value
# 34     Williamsburg - Bushwick  Annual Average 2012  12-01-2011         9.7
# 35     Williamsburg - Bushwick          Summer 2012  06-01-2012        12.3
# 36     Williamsburg - Bushwick          Summer 2013  06-01-2013        12.2
# 39     Williamsburg - Bushwick  Annual Average 2021  01-01-2021         7.2
# 45     Williamsburg - Bushwick       Winter 2021-22  12-01-2021         7.4
# ...                        ...                  ...         ...         ...
# 16801  Williamsburg - Bushwick  Annual Average 2019  01-01-2019         7.5
# 16996  Williamsburg - Bushwick          Summer 2022  06-01-2022        12.7
# 17016  Williamsburg - Bushwick          Summer 2012  06-01-2012        32.3
# 17240  Williamsburg - Bushwick  Annual Average 2019  01-01-2019        19.7
# 17388  Williamsburg - Bushwick                 2005  01-01-2005        42.3
#
# [269 rows x 11 columns]
# Willowbrook
#        Unique ID  Indicator ID  \
# 4622      178565           365
# 5494      549880           375
# 5839      212960           365
# 6129      177263           365
# 6469      131451           648
# ...          ...           ...
# 17491     151759           645
# 17595     151711           644
# 17601     816819           643
# 17602     816820           643
# 17604     151663           643
#
#                                                   Name  \
# 4622                           Fine particles (PM 2.5)
# 5494                            Nitrogen dioxide (NO2)
# 5839                           Fine particles (PM 2.5)
# 6129                           Fine particles (PM 2.5)
# 6469   Asthma emergency department visits due to PM2.5
# ...                                                ...
# 17491           Annual vehicle miles traveled (trucks)
# 17595             Annual vehicle miles traveled (cars)
# 17601                    Annual vehicle miles traveled
# 17602                    Annual vehicle miles traveled
# 17604                    Annual vehicle miles traveled
#
#                                     Measure          Measure Info  \
# 4622                                   Mean                mcg/m3
# 5494                                   Mean                   ppb
# 5839                                   Mean                mcg/m3
# 6129                                   Mean                mcg/m3
# 6469   Estimated annual rate (under age 18)  per 100,000 children
# ...                                     ...                   ...
# 17491                         Million miles       per square mile
# 17595                         Million miles       per square mile
# 17601                         Million miles       per square mile
# 17602                         Million miles       per square mile
# 17604                         Million miles       per square mile
#
#       Geo Type Name  Geo Join ID        Place          Time Period  \
# 4622          UHF42        503.0  Willowbrook  Annual Average 2012
# 5494          UHF42        503.0  Willowbrook          Summer 2017
# 5839          UHF42        503.0  Willowbrook  Annual Average 2014
# 6129          UHF42        503.0  Willowbrook       Winter 2010-11
# 6469          UHF42        503.0  Willowbrook            2009-2011
# ...             ...          ...          ...                  ...
# 17491         UHF42        503.0  Willowbrook                 2005
# 17595         UHF42        503.0  Willowbrook                 2005
# 17601         UHF42        503.0  Willowbrook                 2019
# 17602         UHF42        503.0  Willowbrook                 2010
# 17604         UHF42        503.0  Willowbrook                 2005
#
#        Start_Date  Data Value
# 4622   12-01-2011         8.5
# 5494   06-01-2017        10.2
# 5839   12-01-2013         8.7
# 6129   12-01-2010        11.9
# 6469   01-01-2009        32.8
# ...           ...         ...
# 17491  01-01-2005         1.4
# 17595  01-01-2005        25.0
# 17601  01-01-2019        34.3
# 17602  01-01-2010        31.0
# 17604  01-01-2005        26.4
#
# [170 rows x 11 columns]
# Woodside and Sunnyside (CD2)
#        Unique ID  Indicator ID                                    Name  \
# 254       334314           365                 Fine particles (PM 2.5)
# 257       411097           365                 Fine particles (PM 2.5)
# 794       667777           375                  Nitrogen dioxide (NO2)
# 1203      412788           375                  Nitrogen dioxide (NO2)
# 1322      411095           365                 Fine particles (PM 2.5)
# ...          ...           ...                                     ...
# 17325     154485           645  Annual vehicle miles traveled (trucks)
# 17329     154544           644    Annual vehicle miles traveled (cars)
# 17334     817097           644    Annual vehicle miles traveled (cars)
# 17463     817098           644    Annual vehicle miles traveled (cars)
# 17473     816728           643           Annual vehicle miles traveled
#
#              Measure     Measure Info Geo Type Name  Geo Join ID  \
# 254             Mean           mcg/m3            CD        402.0
# 257             Mean           mcg/m3            CD        402.0
# 794             Mean              ppb            CD        402.0
# 1203            Mean              ppb            CD        402.0
# 1322            Mean           mcg/m3            CD        402.0
# ...              ...              ...           ...          ...
# 17325  Million miles  per square mile            CD        402.0
# 17329  Million miles  per square mile            CD        402.0
# 17334  Million miles  per square mile            CD        402.0
# 17463  Million miles  per square mile            CD        402.0
# 17473  Million miles  per square mile            CD        402.0
#
#                               Place          Time Period  Start_Date  \
# 254    Woodside and Sunnyside (CD2)       Winter 2014-15  12-01-2014
# 257    Woodside and Sunnyside (CD2)  Annual Average 2016  12/31/2015
# 794    Woodside and Sunnyside (CD2)  Annual Average 2020  01-01-2020
# 1203   Woodside and Sunnyside (CD2)          Summer 2016  06-01-2016
# 1322   Woodside and Sunnyside (CD2)       Winter 2015-16  12-01-2015
# ...                             ...                  ...         ...
# 17325  Woodside and Sunnyside (CD2)                 2005  01-01-2005
# 17329  Woodside and Sunnyside (CD2)                 2005  01-01-2005
# 17334  Woodside and Sunnyside (CD2)                 2010  01-01-2010
# 17463  Woodside and Sunnyside (CD2)                 2019  01-01-2019
# 17473  Woodside and Sunnyside (CD2)                 2010  01-01-2010
#
#        Data Value
# 254          10.9
# 257           9.3
# 794          19.2
# 1203         15.8
# 1322          9.8
# ...           ...
# 17325         5.0
# 17329        72.8
# 17334        99.9
# 17463       103.0
# 17473       108.5
#
# [110 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File path for the CSV file
file_path = "/content/Air_Quality.csv"

# Load the CSV file
df = pd.read_csv(file_path)

# Set the limit for the number of places to display
limit = 10

# Drop rows where 'Place' is missing
df_clean = df.dropna(subset=['Place'])

# Aggregate data values by place
place_counts = df_clean.groupby('Place')['Data Value'].sum()

# Sort and limit to top 'limit' places
top_places = place_counts.sort_values(ascending=False).head(limit)
others_count = place_counts.iloc[limit:].sum()
top_places['Others'] = others_count

# Plot the pie chart
plt.figure(figsize=(10, 20))
top_places.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.tab20.colors,
    title=f"Top {limit} Places with Others Grouped (Based on Data Value)"
)
plt.ylabel("")  # Remove y-axis label
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Adjust this if necessary
df = pd.read_csv(file_path)

# Print columns
print(df.columns)

# Set the limit for the number of places to display
limit = 5 # Change this value as needed

# Check if 'Place' and 'Data Value' columns exist
if 'Place' in df.columns and 'Data Value' in df.columns:
    # Calculate average 'Data Value' for each 'Place'
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(limit)

    # Bar graph
    plt.figure(figsize=(8, 8))
    place_data.plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f"Top {limit} Places by Average Data Value (Bar Graph)", fontsize=16)
    plt.xlabel("Place", fontsize=14)
    plt.ylabel("Average Data Value", fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Update this with the actual file path
df = pd.read_csv(file_path)

# Print columns
print(df.columns)

# Line chart for 'Place' over 'Data Value'
if 'Place' in df.columns and 'Data Value' in df.columns:
    # Calculate average 'Data Value' for each place
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(10)  # Top 10 places

    # Line chart
    plt.figure(figsize=(8, 8))
    place_data.plot(kind='line', marker='o', color='blue', linewidth=2)
    plt.title("Top 10 Places by Average Data Value (Line Chart)", fontsize=16)
    plt.xlabel("Place", fontsize=14)
    plt.ylabel("Average Data Value", fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Update this with the actual file path
df = pd.read_csv(file_path)

# Print columns to check the structure
print(df.columns)

# Set the limit for the number of unique places to display
limit = 5

# Scatter plot for 'Place' over 'Data Value'
if 'Place' in df.columns and 'Data Value' in df.columns:
    # Get the top places by the number of occurrences
    top_places = df['Place'].value_counts().head(limit).index
    filtered_df = df[df['Place'].isin(top_places)]

    # Plotting a scatter plot
    plt.figure(figsize=(12, 8))
    sns.scatterplot(data=filtered_df, x='Place', y='Data Value', hue='Place', palette='tab10', marker='o')
    plt.title(f"Scatter Plot of Top {limit} Places vs Data Value", fontsize=10)
    plt.xlabel("Place", fontsize=10)
    plt.ylabel("Data Value", fontsize=10)
    plt.xticks(rotation=35, fontsize=10)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Update with your dataset's actual path
df = pd.read_csv(file_path)

# Print the columns to verify the dataset structure
print(df.columns)

# Set limits for the 'Data Value'
lower_limit = 0  # Adjust as needed
upper_limit = 100  # Adjust as needed

# Check if 'Data Value' exists in the dataset
if 'Data Value' in df.columns:
    # Filter the data based on the limits
    filtered_data = df[(df['Data Value'] >= lower_limit) & (df['Data Value'] <= upper_limit)]

    # Create a histogram for the filtered 'Data Value' column
    plt.figure(figsize=(10, 8))
    plt.hist(filtered_data['Data Value'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f"Histogram of Data Value ({lower_limit} to {upper_limit})", fontsize=16)
    plt.xlabel("Data Value", fontsize=14)
    plt.ylabel("Frequency", fontsize=14)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %% [markdown]
# Top 5 Most and Least Polluted Places

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "/content/Air_Quality.csv"
df = pd.read_csv(file_path)

# Define the limit for the number of places to display
limit = 10  # Change this value as needed

# Group by 'Place' and calculate the average 'Data Value'
place_pollution = df.groupby("Place")["Data Value"].mean().sort_values(ascending=False)

# Get the top 'limit' most polluted places
top_polluted_places = place_pollution.head(limit)

# Get the top 'limit' least polluted places
least_polluted_places = place_pollution.tail(limit)

# Plot bar chart for Top 'limit' Most Polluted Places
plt.figure(figsize=(10, 5))
top_polluted_places.plot(kind='bar', color='red', edgecolor='black')
plt.title(f"Top {limit} Most Polluted Places", fontsize=14)
plt.xlabel("Place", fontsize=12)
plt.ylabel("Average Pollution Level", fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot bar chart for Top 'limit' Least Polluted Places
plt.figure(figsize=(10, 5))
least_polluted_places.plot(kind='bar', color='green', edgecolor='black')
plt.title(f"Top {limit} Least Polluted Places", fontsize=14)
plt.xlabel("Place", fontsize=12)
plt.ylabel("Average Pollution Level", fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Adjust this if necessary
df = pd.read_csv(file_path)

# Print columns
print(df.columns)

# Set the limit for the number of places to display
limit = 5  # Change this value as needed

# Check if 'Place' and 'Data Value' columns exist
if 'Place' in df.columns and 'Data Value' in df.columns:
    # Calculate average 'Data Value' for each 'Place'
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(limit)

    # Horizontal bar graph
    plt.figure(figsize=(8, 6))  # Adjust figure size if necessary
    place_data.plot(kind='barh', color='skyblue', edgecolor='black')  # Changed to 'barh' for horizontal bars
    plt.title(f"Top {limit} Places by Average Data Value (Horizontal Bar Graph)", fontsize=16)
    plt.xlabel("Average Data Value", fontsize=14)
    plt.ylabel("Place", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "/content/Air_Quality.csv"  # Update with the actual file path
df = pd.read_csv(file_path)

# Print columns to check the structure
print(df.columns)

# Define the limit for the number of places to display
limit = 10  # Change this value as needed

# --- 1. Pie Chart: Top Places with Others Grouped ---
if 'Place' in df.columns:
    df_clean = df.dropna(subset=['Place'])  # Drop rows where 'Place' is missing
    place_counts = df_clean['Place'].value_counts()

    top_places = place_counts.head(limit)
    others_count = place_counts.iloc[limit:].sum()
    top_places['Others'] = others_count

    plt.figure(figsize=(12, 8))
    top_places.plot.pie(
        autopct='%1.1f%%',
        startangle=90,
        colors=plt.cm.tab20.colors,
        title=f"Top {limit} Places with Others Grouped"
    )
    plt.ylabel("")
    plt.show()

# --- 2. Bar Graph: Top Places by Average Data Value ---
if 'Place' in df.columns and 'Data Value' in df.columns:
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(limit)

    plt.figure(figsize=(8, 6))
    place_data.plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f"Top {limit} Places by Average Data Value", fontsize=14)
    plt.xlabel("Place", fontsize=12)
    plt.ylabel("Average Data Value", fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.tight_layout()
    plt.show()

# --- 3. Line Chart: Top 10 Places by Average Data Value ---
if 'Place' in df.columns and 'Data Value' in df.columns:
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(10)

    plt.figure(figsize=(8, 6))
    place_data.plot(kind='line', marker='o', color='blue', linewidth=2)
    plt.title("Top 10 Places by Average Data Value (Line Chart)", fontsize=14)
    plt.xlabel("Place", fontsize=12)
    plt.ylabel("Average Data Value", fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# --- 4. Scatter Plot: Top Places vs Data Value ---
if 'Place' in df.columns and 'Data Value' in df.columns:
    top_places = df['Place'].value_counts().head(limit).index
    filtered_df = df[df['Place'].isin(top_places)]

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=filtered_df, x='Place', y='Data Value', hue='Place', palette='tab10', marker='o')
    plt.title(f"Scatter Plot of Top {limit} Places vs Data Value", fontsize=14)
    plt.xlabel("Place", fontsize=12)
    plt.ylabel("Data Value", fontsize=12)
    plt.xticks(rotation=35, fontsize=10)
    plt.tight_layout()
    plt.show()

# --- 5. Histogram: Data Value Distribution within Limits ---
if 'Data Value' in df.columns:
    lower_limit = 0  # Adjust as needed
    upper_limit = 100  # Adjust as needed
    filtered_data = df[(df['Data Value'] >= lower_limit) & (df['Data Value'] <= upper_limit)]

    plt.figure(figsize=(10, 6))
    plt.hist(filtered_data['Data Value'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f"Histogram of Data Value ({lower_limit} to {upper_limit})", fontsize=14)
    plt.xlabel("Data Value", fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# --- 6. Horizontal Bar Graph: Top Places by Average Data Value ---
if 'Place' in df.columns and 'Data Value' in df.columns:
    place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(limit)

    plt.figure(figsize=(8, 6))
    place_data.plot(kind='barh', color='skyblue', edgecolor='black')
    plt.title(f"Top {limit} Places by Average Data Value (Horizontal Bar Graph)", fontsize=14)
    plt.xlabel("Average Data Value", fontsize=12)
    plt.ylabel("Place", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.tight_layout()
    plt.show()

# --- 7. Bar Charts: Most & Least Polluted Places ---
if 'Place' in df.columns and 'Data Value' in df.columns:
    place_pollution = df.groupby("Place")["Data Value"].mean().sort_values(ascending=False)
    top_polluted_places = place_pollution.head(limit)
    least_polluted_places = place_pollution.tail(limit)

    # Top Most Polluted Places
    plt.figure(figsize=(10, 5))
    top_polluted_places.plot(kind='bar', color='red', edgecolor='black')
    plt.title(f"Top {limit} Most Polluted Places", fontsize=14)
    plt.xlabel("Place", fontsize=12)
    plt.ylabel("Average Pollution Level", fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Least Polluted Places
    plt.figure(figsize=(10, 5))
    least_polluted_places.plot(kind='bar', color='green', edgecolor='black')
    plt.title(f"Top {limit} Least Polluted Places", fontsize=14)
    plt.xlabel("Place", fontsize=12)
    plt.ylabel("Average Pollution Level", fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

# Load the dataset
file_path = '/content/Air_Quality.csv'  # Update with the actual file path
df = pd.read_csv(file_path)

# Print columns to check the structure
print("Dataset Columns:", df.columns)

# Create a PDF to save all plots
pdf_file_path = "Air_Quality_Analysis.pdf"
with PdfPages(pdf_file_path) as pdf:
    # 1. Pie Chart: Top Places with Others Grouped
    if 'Place' in df.columns:
        limit = 25  # Set the limit for the number of places to display
        place_counts = df['Place'].value_counts()

        # Select the top 'limit' places and group the rest as 'Others'
        top_places = place_counts.head(limit)
        others_count = place_counts[limit:].sum()
        top_places['Others'] = others_count

        # Plot pie chart
        plt.figure(figsize=(10, 10))
        top_places.plot.pie(
            autopct='%1.1f%%',
            title="Top Places with Others Grouped",
            startangle=90,
            colors=plt.cm.tab20.colors
        )
        plt.ylabel("")  # Remove y-axis label
        pdf.savefig()
        plt.close()

    # 2. Bar Graph: Top Places by Average Data Value
    if 'Place' in df.columns and 'Data Value' in df.columns:
        limit = 5
        place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(limit)

        plt.figure(figsize=(8, 8))
        place_data.plot(kind='bar', color='skyblue', edgecolor='black')
        plt.title(f"Top {limit} Places by Average Data Value (Bar Graph)", fontsize=16)
        plt.xlabel("Place", fontsize=14)
        plt.ylabel("Average Data Value", fontsize=14)
        plt.xticks(rotation=45, fontsize=12)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

    # 3. Line Chart: Top 10 Places by Average Data Value
    if 'Place' in df.columns and 'Data Value' in df.columns:
        place_data = df.groupby('Place')['Data Value'].mean().sort_values(ascending=False).head(10)

        plt.figure(figsize=(8, 8))
        place_data.plot(kind='line', marker='o', color='blue', linewidth=2)
        plt.title("Top 10 Places by Average Data Value (Line Chart)", fontsize=16)
        plt.xlabel("Place", fontsize=14)
        plt.ylabel("Average Data Value", fontsize=14)
        plt.xticks(rotation=45, fontsize=12)
        plt.grid(visible=True, linestyle='--', alpha=0.7)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

    # 4. Scatter Plot: Top Places vs Data Value
    if 'Place' in df.columns and 'Data Value' in df.columns:
        limit = 5
        top_places = df['Place'].value_counts().head(limit).index
        filtered_df = df[df['Place'].isin(top_places)]

        plt.figure(figsize=(12, 8))
        sns.scatterplot(data=filtered_df, x='Place', y='Data Value', hue='Place', palette='tab10', marker='o')
        plt.title(f"Scatter Plot of Top {limit} Places vs Data Value", fontsize=10)
        plt.xlabel("Place", fontsize=10)
        plt.ylabel("Data Value", fontsize=10)
        plt.xticks(rotation=35, fontsize=10)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

    # 5. Histogram: Data Value Distribution
    if 'Data Value' in df.columns:
        plt.figure(figsize=(10, 8))
        plt.hist(df['Data Value'].dropna(), bins=30, color='skyblue', edgecolor='black', alpha=0.7)
        plt.title("Histogram of Data Value", fontsize=16)
        plt.xlabel("Data Value", fontsize=14)
        plt.ylabel("Frequency", fontsize=14)
        plt.grid(visible=True, linestyle='--', alpha=0.7)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

    # 6. Most and Least Polluted Places
    if 'Place' in df.columns and 'Data Value' in df.columns:
        limit = 10
        place_pollution = df.groupby("Place")["Data Value"].mean().sort_values(ascending=False)
        top_polluted_places = place_pollution.head(limit)
        least_polluted_places = place_pollution.tail(limit)

        # Most Polluted Places
        plt.figure(figsize=(10, 5))
        top_polluted_places.plot(kind='bar', color='red', edgecolor='black')
        plt.title(f"Top {limit} Most Polluted Places", fontsize=14)
        plt.xlabel("Place", fontsize=12)
        plt.ylabel("Average Pollution Level", fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=10)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

        # Least Polluted Places
        plt.figure(figsize=(10, 5))
        least_polluted_places.plot(kind='bar', color='green', edgecolor='black')
        plt.title(f"Top {limit} Least Polluted Places", fontsize=14)
        plt.xlabel("Place", fontsize=12)
        plt.ylabel("Average Pollution Level", fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=10)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        pdf.savefig()
        plt.close()

print(f"All plots have been saved to {pdf_file_path}.")
# Out:
# Dataset Columns: Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Place', 'Time Period', 'Start_Date',
#        'Data Value'],
#       dtype='object')
# All plots have been saved to Air_Quality_Analysis.pdf.
